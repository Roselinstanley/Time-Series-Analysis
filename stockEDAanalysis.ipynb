# %% [markdown]
# !pip install yfinance

# %%
import yfinance as yf
from datetime import date
ticker="RELIANCE.NS"
stk_dataset=yf.download(ticker,start=date(2021,6,1),end=date(2022,1,5))
stk_dataset
# Out:
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  1 of 1 completed
# Price             Close         High          Low         Open      Volume
# Ticker      RELIANCE.NS  RELIANCE.NS  RELIANCE.NS  RELIANCE.NS RELIANCE.NS
# Date
# 2021-06-01   994.095642  1009.266717   983.828756   992.766424    28013832
# 2021-06-02  1008.922974  1012.704286   988.641369   988.641369    24630162
# 2021-06-03  1012.773071  1031.267131  1006.562578  1017.975194    23974257
# 2021-06-04  1003.995850  1015.889768  1001.131193  1015.133505    14468646
# 2021-06-07  1020.908569  1027.600364  1001.474941  1009.266759    16336573
# ...                 ...          ...          ...          ...         ...
# 2021-12-29  1105.003052  1112.592041  1095.620224  1099.713753    15425312
# 2021-12-30  1085.041626  1106.129843  1078.832475  1103.853146    29333171
# 2021-12-31  1089.204102  1096.448070  1085.455594  1091.434812     9477290
# ...

# %%
stk_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 150 entries, 2021-06-01 to 2022-01-04
# Data columns (total 5 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   (Close, RELIANCE.NS)   150 non-null    float64
#  1   (High, RELIANCE.NS)    150 non-null    float64
#  2   (Low, RELIANCE.NS)     150 non-null    float64
#  3   (Open, RELIANCE.NS)    150 non-null    float64
#  4   (Volume, RELIANCE.NS)  150 non-null    int64
# dtypes: float64(4), int64(1)
# memory usage: 7.0 KB

# %%
dataset=stk_dataset

# %%
dataset.describe()
# Out:
# Price         Close         High          Low         Open        Volume
# Ticker  RELIANCE.NS  RELIANCE.NS  RELIANCE.NS  RELIANCE.NS   RELIANCE.NS
# count    150.000000   150.000000   150.000000   150.000000  1.500000e+02
# mean    1073.798934  1085.731613  1063.240676  1075.419902  1.458498e+07
# std       87.022472    89.013199    85.040338    87.412976  9.640998e+06
# min      936.113525   946.554069   927.351602   944.714283  1.705656e+06
# 25%      994.208908  1005.242274   983.124138   991.050287  9.784558e+06
# 50%     1088.732666  1101.725874  1079.407403  1090.537924  1.208794e+07
# 75%     1141.941833  1149.726311  1129.063501  1142.315619  1.575945e+07
# max     1256.483765  1265.452592  1245.514281  1261.497246  9.146198e+07

# %%
from EDAcentral import EDA

# %%
EDAobj=EDA(dataset)
centraluni=EDAobj.central()
centraluni
# Out:
# C:\Users\Admin\Desktop\AI\Time Series Analysis\EDAcentral.py:15: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   centraluni[cname]["Mean"]=self.dataset[cname].mean()
# ...

# %%
Lesser=[]
Greater=[]

# %%
Lesser,Greater=EDAobj.outlierscheck()

# %%
Lesser
# Out:
# []

# %%
Greater
# Out:
# [('Volume', 'RELIANCE.NS')]

# %%
dataset1=EDAobj.outliersreplace()
# Out:
# C:\Users\Admin\Desktop\AI\Time Series Analysis\EDAcentral.py:38: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   self.dataset[cname][self.dataset[cname] > centraluni[cname]["Greater"]]=centraluni[cname]["Greater"]
# ...

# %%
EDAobj1=EDA(dataset1)

# %%
Lesser=[]
Greater=[]

# %%
central=EDAobj1.central()
# Out:
# C:\Users\Admin\Desktop\AI\Time Series Analysis\EDAcentral.py:15: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   centraluni[cname]["Mean"]=self.dataset[cname].mean()
# ...

# %%
central
# Out:
# Price          Close         High          Low         Open           Volume
# Ticker   RELIANCE.NS  RELIANCE.NS  RELIANCE.NS  RELIANCE.NS      RELIANCE.NS
# Mean     1073.798934  1085.731613  1063.240676  1075.419902  13485856.989167
# Median   1088.732666  1101.725874  1079.407403  1090.537924       12087939.0
# Mode      959.432373   946.554069   927.351602   944.714283     24721794.875
# Q1:25     994.208908  1005.242274   983.124138   991.050287        9784558.0
# Q2:50    1088.732666  1101.725874  1079.407403  1090.537924       12087939.0
# Q3:75    1141.941833  1149.726311  1129.063501  1142.315619      15759452.75
# Q4:100   1256.483765  1265.452592  1245.514281  1261.497246     24721794.875
# IQR       147.732925   144.484037   145.939363   151.265332       5974894.75
# 1.5*IQR   221.599388   216.726055   218.909044   226.897998      8962342.125
# Lesser     772.60952   788.516219   764.215094   764.152289       822215.875
# ...

# %%
Lesser,Greater=EDAobj1.outlierscheck()

# %%
Lesser
# Out:
# []

# %%
Greater
# Out:
# []

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb
from scipy.stats import norm
from statsmodels.distributions.empirical_distribution import ECDF
import pandas as pd

# %%
np.percentile(dataset1["Low"],89)
# Out:
# 1175.005253679033

# %%
def cal_pdf(dataset1):
    ax=sb.distplot(dataset1["Low"],kde=True,kde_kws={'color':'pink'},color='green')
    plt.axvline(200,color='yellow')
    plt.axvline(1000,color='yellow')
    plt.show()
    mean=dataset1["Low"].mean()
    std=dataset1["Low"].std()
    norms=norm(mean,std)
    probabilities=[norms.pdf(value) for value in range(200,1000)]
    probsum=sum(probabilities)
    probper=probsum *100
    low_values=dataset1["Low"].dropna().values.ravel()
    ecdf=ECDF(low_values)
    ecdfout=ecdf(700)
    print("The are of Low between ({},{}),({},{}),{}".format(200,1000,probsum,probper,ecdfout))
    return

# %%
cal_pdf(dataset1)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_21396\1866443354.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax=sb.distplot(dataset1["Low"],kde=True,kde_kws={'color':'pink'},color='green')
# The are of Low between (200,1000),([0.22676623],[22.67662255]),0.0

# %%
def std_normal(dataset1):
    mean=dataset1["Low"].mean()
    std=dataset1["Low"].std()
    values=[i for i in dataset1["Low"].dropna().values.ravel()]
    z_score=[((j-mean)/std) for j in values]
    df=pd.DataFrame({"Z_score": z_score})
    print("The Z_Score plot of plot")
    sb.distplot(z_score,kde=True)
    plt.show()
    display(df["Z_score"])

# %%
std_normal(dataset1)
# Out:
# The Z_Score plot of plot
# C:\Users\Admin\AppData\Local\Temp\ipykernel_21396\1535715807.py:8: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sb.distplot(z_score,kde=True)
# 0      Ticker
# RELIANCE.NS   -0.933815
# dtype: float64
# 1      Ticker
# RELIANCE.NS   -0.877223
# dtype: float64
# 2      Ticker
# RELIANCE.NS   -0.666485
# dtype: float64
# 3      Ticker
# RELIANCE.NS   -0.730353
# dtype: float64
# 4      Ticker
# RELIANCE.NS   -0.726311
# dtype: float64
#                            ...
# 145    Ticker
# RELIANCE.NS    0.380755
# dtype: float64
# 146    Ticker
# RELIANCE.NS    0.183346
# dtype: float64
# 147    Ticker
# ...

# %%
 def frequency(dataset1):
     value_counts = dataset1["Low"].value_counts().sort_index()

     # Create the frequency table directly from value_counts
     freq = pd.DataFrame({ 
                         "Unique Values": value_counts.index,
                         "Frequency": value_counts.values
     })

     # Calculate relative frequency and CRF
     freq["Relative Frequency"] = freq["Frequency"] / freq["Frequency"].sum()
     freq["CRF"] = freq["Relative Frequency"].cumsum()

     # Display result
     display(freq)

# %%
dataset["Low"]=dataset1["Low"].dropna().values.ravel()
frequency(dataset)
# Out:
#              Unique Values  Frequency  Relative Frequency       CRF
# 0     (927.3516023082251,)          1            0.006667  0.006667
# 1     (934.1817273276183,)          1            0.006667  0.013333
# 2     (938.8041261913924,)          1            0.006667  0.020000
# 3     (939.1950977228437,)          1            0.006667  0.026667
# 4     (939.8389235927302,)          1            0.006667  0.033333
# ..                     ...        ...                 ...       ...
# 145   (1224.495031941363,)          1            0.006667  0.973333
# 146  (1227.7146012557143,)          1            0.006667  0.980000
# 147  (1235.9476071876143,)          1            0.006667  0.986667
# 148  (1237.9253917840351,)          1            0.006667  0.993333
# 149  (1245.5142813861512,)          1            0.006667  1.000000
#
# [150 rows x 4 columns]

# %%
dataset1
# Out:
# Price             Close         High          Low         Open        Volume
# Ticker      RELIANCE.NS  RELIANCE.NS  RELIANCE.NS  RELIANCE.NS   RELIANCE.NS
# Date
# 2021-06-01   994.095642  1009.266717   983.828756   992.766424  2.472179e+07
# 2021-06-02  1008.922974  1012.704286   988.641369   988.641369  2.463016e+07
# 2021-06-03  1012.773071  1031.267131  1006.562578  1017.975194  2.397426e+07
# 2021-06-04  1003.995850  1015.889768  1001.131193  1015.133505  1.446865e+07
# 2021-06-07  1020.908569  1027.600364  1001.474941  1009.266759  1.633657e+07
# ...                 ...          ...          ...          ...           ...
# 2021-12-29  1105.003052  1112.592041  1095.620224  1099.713753  1.542531e+07
# 2021-12-30  1085.041626  1106.129843  1078.832475  1103.853146  2.472179e+07
# 2021-12-31  1089.204102  1096.448070  1085.455594  1091.434812  9.477290e+06
# 2022-01-03  1105.623901  1107.509713  1087.088421  1087.755347  5.421611e+06
# ...
